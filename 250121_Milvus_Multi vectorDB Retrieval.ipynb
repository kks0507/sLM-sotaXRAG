# %% [markdown]
# ## 종속성 설치

# %%
# !pip install --upgrade --quiet  langchain langchain-core langchain-community langchain-text-splitters langchain-milvus langchain-openai bs4
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 24.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 412.2/412.2 kB 42.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 96.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.3/54.3 kB 6.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 26.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 72.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 93.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 6.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 MB 50.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 6.0 MB/s eta 0:00:00

# %%
# !pip install --upgrade--quiet tokenizers
# Out:
# Usage:
#   pip3 install [options] <requirement specifier> [package-index-options] ...
#   pip3 install [options] -r <requirements file> [package-index-options] ...
#   pip3 install [options] [-e] <vcs project url> ...
#   pip3 install [options] [-e] <local project path> ...
#   pip3 install [options] <archive url/path> ...
#
# no such option: --upgrade--quiet

# %%
# !pip install bitsandbytes
# Out:
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.45.0-py3-none-manylinux_2_24_x86_64.whl.metadata (2.9 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (2.5.1+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (1.26.4)
# Requirement already satisfied: typing_extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (4.12.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->bitsandbytes) (3.16.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->bitsandbytes) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->bitsandbytes) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->bitsandbytes) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch->bitsandbytes) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch->bitsandbytes) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch->bitsandbytes) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch->bitsandbytes) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch->bitsandbytes) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch->bitsandbytes) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->bitsandbytes) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch->bitsandbytes) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->bitsandbytes) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->bitsandbytes) (12.6.85)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->bitsandbytes) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->bitsandbytes) (3.0.2)
# Downloading bitsandbytes-0.45.0-py3-none-manylinux_2_24_x86_64.whl (69.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 MB 31.8 MB/s eta 0:00:00
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.45.0

# %% [markdown]
# ## LLM 모델 준비

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig

# 1. 모델 ID 설정
base_model_id = 'Bllossom/llama-3.2-Korean-Bllossom-3B'

# 2. BitsAndBytesConfig 설정
bnb_config = BitsAndBytesConfig(
    load_in_8bit=True, # 4bit quantization으로 모델을 불러와 메모리 소모를 줄임
)

# 3. 모델 로드
model = AutoModelForCausalLM.from_pretrained(base_model_id, quantization_config=bnb_config)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/904 [00:00<?, ?B/s]
# `low_cpu_mem_usage` was None, now default to True since model is quantized.
# model.safetensors.index.json:   0%|          | 0.00/20.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/1.46G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/180 [00:00<?, ?B/s]

# %%
# 4. 토크나이저 로드
tokenizer = AutoTokenizer.from_pretrained(
    base_model_id,
    model_max_length=512,  # 최대 토큰 길이
    padding_side="left",   # 입력 패딩 방향
    add_eos_token=True     # EOS 토큰 추가
)

tokenizer.pad_token = tokenizer.eos_token
# Out:
# tokenizer_config.json:   0%|          | 0.00/54.7k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/296 [00:00<?, ?B/s]

# %%
from transformers import pipeline
from langchain.llms import HuggingFacePipeline
# LLM 파이프라인 설정 (LangChain과 통합)
llm_pipeline = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    max_new_tokens=500
)
llm = HuggingFacePipeline(pipeline=llm_pipeline)
# Out:
# Device set to use cuda:0
# <ipython-input-6-0e279de07470>:10: LangChainDeprecationWarning: The class `HuggingFacePipeline` was deprecated in LangChain 0.0.37 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFacePipeline``.
#   llm = HuggingFacePipeline(pipeline=llm_pipeline)

# %% [markdown]
# ## 데이터 준비
#
# <br>
# Langchain csvLoader를 사용해 문서를 로드.

# %%
from google.colab import drive

# 구글 드라이브 마운트
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = '/content/drive/My Drive/Colab Notebooks/RAG_MilVus/서지.csv'

# %%
file_path = '/content/drive/My Drive/Colab Notebooks/RAG_MilVus/실라버스.csv'

# %%
import pandas as pd
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.docstore.document import Document

# CSV 파일 로드
file_path = '/content/drive/My Drive/Colab Notebooks/RAG_MilVus/서지.csv'
data = pd.read_csv(file_path)

# Replace NaN values in '책 소개' with an empty string
data['책 소개'] = data['책 소개'].fillna('')

# CSV 데이터를 LangChain Document로 변환
# Change metadata keys to start with an underscore and use English or abbreviations
bibliography_docs = [
    Document(
        page_content=row['책 소개'],  # 책 소개를 주요 내용으로 설정
        metadata={
            "title": row['제목'],       # Changed to 'title'
            "author": row['저자'],       # Changed to 'author'
            "publisher": row['출판사'],   # Changed to 'publisher'
            "isbn": row['ISBN']       # Changed to 'isbn'
        }
    )
    for _, row in data.iterrows()
]

# 텍스트 분할
text_splitter = RecursiveCharacterTextSplitter(chunk_size=2000, chunk_overlap=200)
docs1 = text_splitter.split_documents(bibliography_docs)

# 첫 번째 분할된 문서 출력
print(docs1[1])
# Out:
# page_content='<전염병의 세계사>와 <전쟁의 세계사>로 국내 독자들에게 알려진 바 있으며, 현존하는 가장 탁월한 역사가 중 한명으로 꼽히는 윌리엄 맥닐 시카고대 역사학과 교수의 책. 해외에서입니다.' metadata={'title': '세계의 역사', 'author': '윌리엄 맥닐', 'publisher': '이산', 'isbn': 271590}

# %%
import pandas as pd
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.docstore.document import Document

# CSV 파일 로드
file_path = '/content/drive/My Drive/Colab Notebooks/RAG_MilVus/실라버스.csv'
data = pd.read_csv(file_path)

# Replace NaN values in '책 소개' with an empty string
data['요약 설명'] = data['요약 설명'].fillna('')

# CSV 데이터를 LangChain Document로 변환
# Change metadata keys to start with an underscore and use English or abbreviations
syllabus_docs = [
    Document( # Create Document objects instead of dictionaries
        page_content=row['요약 설명'],  # 요약 설명을 주요 내용으로 설정
        metadata={
            "title": row['강의 명'],        # Changed to '_title'
            "course_id": row['강의 번호'],  # Changed to '_course_id'
            "department": row['주관 학과'], # Changed to '_department'
            "reference": row['참고문헌']   # Changed to '_reference'
        }
    )
    for _, row in data.iterrows()
]

# 텍스트 분할
text_splitter = RecursiveCharacterTextSplitter(chunk_size=2000, chunk_overlap=200)
docs2 = text_splitter.split_documents(syllabus_docs)

# 첫 번째 분할된 문서 출력
print(docs2[22])
# Out:
# page_content='인적자원 관리와 조직의 동기부여 및 성과 평가 기법을 탐구합니다.' metadata={'title': '인적자원관리', 'course_id': 1022, 'department': '경영학', 'reference': 'Human Resource Management'}

# %% [markdown]
# ## 임베딩 모델 활용 데이터 임베딩 이후, Milvus 벡터 DB에 저장
#
# <br>
#
# 문서로 Milvus 벡터 스토어를 초기화하여 Milvus 벡터 스토어에 문서를 로드하고 내부적으로 인덱스를 구축.

# %%
# !pip install pymilvus
# Out:
# Requirement already satisfied: pymilvus in /usr/local/lib/python3.11/dist-packages (2.5.3)
# Requirement already satisfied: setuptools>69 in /usr/local/lib/python3.11/dist-packages (from pymilvus) (75.1.0)
# Requirement already satisfied: grpcio<=1.67.1,>=1.49.1 in /usr/local/lib/python3.11/dist-packages (from pymilvus) (1.67.1)
# Requirement already satisfied: protobuf>=3.20.0 in /usr/local/lib/python3.11/dist-packages (from pymilvus) (4.25.5)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from pymilvus) (1.0.1)
# Requirement already satisfied: ujson>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from pymilvus) (5.10.0)
# Requirement already satisfied: pandas>=1.2.4 in /usr/local/lib/python3.11/dist-packages (from pymilvus) (2.2.2)
# Requirement already satisfied: milvus-lite>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from pymilvus) (2.4.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from milvus-lite>=2.4.0->pymilvus) (4.67.1)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2.4->pymilvus) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2.4->pymilvus) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2.4->pymilvus) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2.4->pymilvus) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.2.4->pymilvus) (1.17.0)

# %%
from langchain_milvus import Milvus
from langchain.embeddings import HuggingFaceEmbeddings

#  Milvus 컬렉션 생성
embedding_model = HuggingFaceEmbeddings(model_name="jhgan/ko-sroberta-multitask", model_kwargs={'device': 'cuda:0'})

# 서지 컬렉션
bibliography_store = Milvus.from_documents(
    documents=docs1,
    embedding=embedding_model,
    connection_args={
        "uri": "./milvus_demo.db",
    },
    collection_name="bibliography_collection",
    drop_old=True,
    # Specify index_params for FLAT index
    index_params={"index_type": "FLAT"}
)

# 실라버스 컬렉션
syllabus_store = Milvus.from_documents(
    documents=docs2,
    embedding=embedding_model,
    connection_args={
        "uri": "./milvus_demo.db",
    },
    collection_name="syllabus_collection",
    drop_old=True,
    # Specify index_params for FLAT index
    index_params={"index_type": "FLAT"}
)
# Out:
# <ipython-input-13-55cbef13c5ba>:5: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embedding_model = HuggingFaceEmbeddings(model_name="jhgan/ko-sroberta-multitask", model_kwargs={'device': 'cuda:0'})
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/123 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/4.86k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/744 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/443M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/585 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/248k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/495k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/156 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %% [markdown]
# ### 서지 컬렉션 검색
# 테스트 쿼리 문제를 사용하여 Milvus 벡터 스토어에서 문서를 검색합니다. 상위 2개 문서를 살펴보기.

# %%
query = "거시경제학"
results1 = bibliography_store.similarity_search(query, k=2)

# %%
results1
# Out:
# [Document(metadata={'author': '정운찬, 김영식', 'isbn': 599922, 'pk': 455459354343899243, 'publisher': '율곡출판사', 'title': '거시경제론'}, page_content='이 책은 거시경제론을 다룬 개론서입니다. 거시경제론의 기초적이고 전반적인 내용을 학습할 수 있도록 구성했습니다.'),
#  Document(metadata={'author': 'Andrew B. Abel, Ben S. Bernanke, Dean Croushore', 'isbn': 514313, 'pk': 455459354343899241, 'publisher': '지필미디어', 'title': '거시경제학'}, page_content='『거시경제학』은 경제학을 공부하는 학생들을 위해 고전학파와 케인즈파의 여러 가정을 명료하게 설명하는 단일 경제모형을 바탕으로 하나로 통일된 접근방법을 제시한 책이다. 특히 세계입니다.')]

# %% [markdown]
# ### 실라버스 컬렉션 검색
# 테스트 쿼리 문제를 사용하여 Milvus 벡터 스토어에서 문서를 검색합니다. 상위 2개 문서를 살펴보기.

# %%
query = "거시경제학"
results2 = syllabus_store.similarity_search(query, k=2)

# %%
results2
# Out:
# [Document(metadata={'course_id': 1041, 'department': '경제학', 'pk': 455459355089961701, 'reference': 'Macroeconomics', 'title': '거시경제학'}, page_content='국가 경제와 정책의 영향을 다루는 거시경제학 원리를 탐구합니다.'),
#  Document(metadata={'course_id': 1045, 'department': '경제학', 'pk': 455459355089961705, 'reference': 'Financial Economics', 'title': '금융 경제학'}, page_content='금융 시장의 구조와 경제학적 원리를 탐구합니다.')]

# %% [markdown]
# ## RAG 체인 구축하기
# Langchain 기반 RAG 체인을 구축합니다.

# %%
# LangChain Prompt 설정
PROMPT_TEMPLATE = """
당신은 서지 및 강의 정보를 분석하여 추천하는 AI 비서입니다.
아래 제공된 정보(context)와 <question> 태그 안에 있는 사용자 질문을 기반으로 **<지정 응답 형식>만** 따르세요.
하나, 질문에 대해 알맞은 도서를 추천하고 이유를 제시하라.
둘, 추천 도서에 대해 학습 단계별 로드맵을 작성하고, 각 단계에 대한 이유를 제시하라.
셋, 질문에 대해 알맞은 강의를 추천하고 이유를 제시하라.

<정보>
{context}
</정보>

<질문>
{question}
</질문>

<지정 응답 형식>:
1. 추천 도서 목록:
- 추천 1: [도서명] (저자)
  이유: [추천 이유]
- 추천 2: [도서명] (저자)
  이유: [추천 이유]

2. 도서 로드맵:
- 단계 1: [도서명] (저자)
  이유: [이 도서를 먼저 읽어야 하는 이유]
- 단계 2: [도서명] (저자)
  이유: [이 도서를 다음 단계로 추천하는 이유]

3. 추천 강의 목록:
- 추천 1: [강의명]
  이유: [추천 이유]
- 추천 2: [강의명]
  이유: [추천 이유]
========================= 실제 생성 종료 =======================================
</지정 응답 형식>

반드시 위 <지정 응답 형식>만 사용하여 작성하세요. 형식을 벗어나거나 불필요한 추가 정보를 포함하지 마세요.
지정 응답 형식에 따른 생성이 끝나면 추가, 반복 생성 없이 종료하세요.
========================= 실제 생성 ============================================
"""

# %%
from langchain_core.prompts import PromptTemplate
# PromptTemplate 설정
prompt = PromptTemplate(
    template=PROMPT_TEMPLATE,
    input_variables=["context", "question"]
)

# %%
# 두 개의 컬렉션에서 데이터를 검색하는 함수
def search_collections(query, syllabus_store, bibliography_store, top_k=2):
    query_embedding = embedding_model.embed_query(query)

    # 실라버스 컬렉션에서 검색
    syllabus_results = syllabus_store.similarity_search_by_vector(query_embedding, k=top_k)
    syllabus_context = "\n".join(
        f"강의명: {res.metadata['title']}, 강의 번호: {res.metadata['course_id']}, 주관 학과: {res.metadata['department']}\n{res.page_content}"
        for res in syllabus_results
    )

    # 서지 컬렉션에서 검색
    bibliography_results = bibliography_store.similarity_search_by_vector(query_embedding, k=top_k)
    bibliography_context = "\n".join(
        f"도서명: {res.metadata['title']}, 저자: {res.metadata['author']}, 출판사: {res.metadata['publisher']}, ISBN: {res.metadata['isbn']}\n{res.page_content}"
        for res in bibliography_results
    )

    # 두 결과를 합침
    combined_context = f"실라버스 정보:\n{syllabus_context}\n\n서지 정보:\n{bibliography_context}"
    return combined_context

# %%
# 사용자 질의 처리 함수
def handle_query(query, syllabus_store, bibliography_store):
    # 검색 결과 가져오기
    context = search_collections(query, syllabus_store, bibliography_store)

    # Prompt에 맞게 데이터를 전달
    formatted_prompt = prompt.format(context=context, question=query)

    #LLM을 통해 결과 생성
    response = llm(formatted_prompt)

    # Check if the response is a string and convert to a dictionary if necessary
    if isinstance(response, str):
        response = {"generated_text": response}

    return response

# %%
# 사용자 질의 테스트
query = "거시경제와 미시경제의 차이를 알 수 있는 강의 및 도서를 추천해줘."
response = handle_query(query, syllabus_store, bibliography_store)

print("추천 결과:")
print(response["generated_text"]) # Access the 'generated_text' key directly
# Out:
# 추천 결과:
#
# 당신은 서지 및 강의 정보를 분석하여 추천하는 AI 비서입니다.
# 아래 제공된 정보(context)와 <question> 태그 안에 있는 사용자 질문을 기반으로 **<지정 응답 형식>만** 따르세요.
# 하나, 질문에 대해 알맞은 도서를 추천하고 이유를 제시하라.
# 둘, 추천 도서에 대해 학습 단계별 로드맵을 작성하고, 각 단계에 대한 이유를 제시하라.
# 셋, 질문에 대해 알맞은 강의를 추천하고 이유를 제시하라.
#
# <정보>
# 실라버스 정보:
# 강의명: 거시경제학, 강의 번호: 1041, 주관 학과: 경제학
# 국가 경제와 정책의 영향을 다루는 거시경제학 원리를 탐구합니다.
# 강의명: 미시경제학, 강의 번호: 1040, 주관 학과: 경제학
# 소비자의 선택과 기업의 생산 결정을 분석하는 미시경제학 이론을 학습합니다.
#
# 서지 정보:
# 도서명: 거시경제론, 저자: 정운찬, 김영식, 출판사: 율곡출판사, ISBN: 599922
# 이 책은 거시경제론을 다룬 개론서입니다. 거시경제론의 기초적이고 전반적인 내용을 학습할 수 있도록 구성했습니다.
# 도서명: Economic Policy, 저자: Ava, 출판사: Publisher23, ISBN: 411480
# Economic Policy은 실라버스에 포함된 참고문헌으로 학습 자료로 사용됩니다.
# </정보>
#
# <질문>
# 거시경제와 미시경제의 차이를 알 수 있는 강의 및 도서를 추천해줘.
# </질문>
#
# <지정 응답 형식>:
# 1. 추천 도서 목록:
# - 추천 1: [도서명] (저자)
#   이유: [추천 이유]
# - 추천 2: [도서명] (저자)
#   이유: [추천 이유]
#
# 2. 도서 로드맵:
# - 단계 1: [도서명] (저자)
#   이유: [이 도서를 먼저 읽어야 하는 이유]
# - 단계 2: [도서명] (저자)
#   이유: [이 도서를 다음 단계로 추천하는 이유]
#
# 3. 추천 강의 목록:
# - 추천 1: [강의명]
#   이유: [추천 이유]
# - 추천 2: [강의명]
#   이유: [추천 이유]
# ========================= 실제 생성 종료 =======================================
# </지정 응답 형식>
#
# 반드시 위 <지정 응답 형식>만 사용하여 작성하세요. 형식을 벗어나거나 불필요한 추가 정보를 포함하지 마세요.
# 지정 응답 형식에 따른 생성이 끝나면 추가, 반복 생성 없이 종료하세요.
# ========================= 실제 생성 ============================================
# 1. 추천 도서 목록:
# - 추천 1: 거시경제론 (저자: 정운찬, 김영식)
#   이유: 거시경제론을 다룬 개론서로 거시경제학 원리를 학습할 수 있도록 구성되어 있어 거시경제와 미시경제의 차이를 알 수 있는 데 중요한 역할을 할 수 있습니다.
# - 추천 2: Economic Policy (저자: Ava)
#   이유: 실라버스에 포함된 참고문헌으로 학습 자료로 사용되어 경제 정책과 거시경제의 관계를 이해할 수 있는 데 도움을 줄 수 있습니다.
#
# 2. 도서 로드맵:
# - 단계 1: 거시경제론 (저자: 정운찬, 김영식)
#   이유: 거시경제론은 거시경제학의 기초적이고 전반적인 내용을 다루므로, 거시경제의 원리를 이해하기 위해 먼저 읽어야 합니다.
# - 단계 2: Economic Policy (저자: Ava)
#   이유: Economic Policy는 거시경제의 정책적 측면을 다루므로, 거시경제의 정책적 요소와 미시경제와의 관계를 이해하기 위해 Economic Policy를 읽는 것이 중요합니다.
#
# 3. 추천 강의 목록:
# - 추천 1: 거시경제학 (강의 번호: 1041)
#   이유: 거시경제학 강의는 거시경제학의 원리를 직접적으로 다루므로, 거시경제와 미시경제의 차이를 이해하는 데 중요한 역할을 할 수 있습니다.
# - 추천 2: 미시경제학 (강의 번호: 1040)
#   이유: 미시경제학 강의는 미시경제학 이론을 다루므로, 미시경제와 거시경제의 차이를 이해하기 위한 중요한 기초를 제공합니다.
#
# ========================= 실제 생성 종료 ============================================
# 이제 <지정 응답 형식>을 따르며, <question>에 대한 응답을 작성해 주세요.
# 1. 추천 도서 목록:
# - 추천 1: 거시경제론 (저자: 정운찬, 김영식)
#   이유: 거시경제론을 다룬 개론서로 거시경제학 원리를 학습할 수 있도록 구성되어 있어 거시경제와 미시경제의 차

# %%
# 사용자 질의 테스트
query = "케인즈의 거시경제학 이론이 현대 경제정책에 미친 영향은 무엇인가요?"
response = handle_query(query, syllabus_store, bibliography_store)

print("추천 결과:")
print(response["generated_text"]) # Access the 'generated_text' key directly
# Out:
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# 추천 결과:
#
# 당신은 서지 및 강의 정보를 분석하여 추천하는 AI 비서입니다.
# 아래 제공된 정보(context)와 <question> 태그 안에 있는 사용자 질문을 기반으로 **<지정 응답 형식>만** 따르세요.
# 하나, 질문에 대해 알맞은 도서를 추천하고 이유를 제시하라.
# 둘, 추천 도서에 대해 학습 단계별 로드맵을 작성하고, 각 단계에 대한 이유를 제시하라.
# 셋, 질문에 대해 알맞은 강의를 추천하고 이유를 제시하라.
#
# <정보>
# 실라버스 정보:
# 강의명: 거시경제학, 강의 번호: 1041, 주관 학과: 경제학
# 국가 경제와 정책의 영향을 다루는 거시경제학 원리를 탐구합니다.
# 강의명: 공공 경제학, 강의 번호: 1049, 주관 학과: 경제학
# 공공 재정과 정책의 경제학적 이론을 다룹니다.
#
# 서지 정보:
# 도서명: 자본의 한계, 저자: 데이비드 하비, 출판사: 한울, ISBN: 148551
# <<자본론>>에 나타난 맑스의 주장을 토대로 자본주의 적 생산양삭, 고정자본, 지대이론 등의 다양한 측면 을 고찰 분석한 미국 교수의 저술.
# 도서명: 아담의 오류, 저자: 던컨 폴리, 출판사: 후마니타스, ISBN: 727469
# 대표적인 마르크스주의 경제학자 던컨 폴리의 경제학사 강의. 아담의 오류라는 일관된 관점을 통해 살펴본 주요 경제학자들의 이론과 비전이 담겨 있다. 경제 사상사를 이루고 있는입니다.
# </정보>
#
# <질문>
# 케인즈의 거시경제학 이론이 현대 경제정책에 미친 영향은 무엇인가요?
# </질문>
#
# <지정 응답 형식>:
# 1. 추천 도서 목록:
# - 추천 1: [도서명] (저자)
#   이유: [추천 이유]
# - 추천 2: [도서명] (저자)
#   이유: [추천 이유]
#
# 2. 도서 로드맵:
# - 단계 1: [도서명] (저자)
#   이유: [이 도서를 먼저 읽어야 하는 이유]
# - 단계 2: [도서명] (저자)
#   이유: [이 도서를 다음 단계로 추천하는 이유]
#
# 3. 추천 강의 목록:
# - 추천 1: [강의명]
#   이유: [추천 이유]
# - 추천 2: [강의명]
#   이유: [추천 이유]
# ========================= 실제 생성 종료 =======================================
# </지정 응답 형식>
#
# 반드시 위 <지정 응답 형식>만 사용하여 작성하세요. 형식을 벗어나거나 불필요한 추가 정보를 포함하지 마세요.
# 지정 응답 형식에 따른 생성이 끝나면 추가, 반복 생성 없이 종료하세요.
# ========================= 실제 생성 ============================================
# 1. 추천 도서 목록:
# - 추천 1: 자본의 한계 (데이비드 하비)
#   이유: 케인즈의 거시경제학 이론을 이해하기 위해 자본론을 읽어야 한다.
# - 추천 2: 아담의 오류 (던컨 폴리)
#   이유: 케인즈의 거시경제학 이론을 이해하기 위해 마르크스주의 경제학사에 대한 배경을 읽어야 한다.
#
# 2. 도서 로드맵:
# - 단계 1: 자본의 한계 (데이비드 하비)
#   이유: 케인즈의 거시경제학 이론을 이해하기 위해서는 자본론의 개념과 이론을 먼저 이해해야 한다. 케인즈의 거시경제학 이론은 자본론의 주요 주제 중 하나이므로, 자본론을 먼저 읽어야 한다.
# - 단계 2: 아담의 오류 (던컨 폴리)
#   이유: 자본론을 읽은 후, 자본론의 개념과 이론을 바탕으로 마르크스주의 경제학사에 대한 배경을 읽어야 한다. 마르크스주의 경제학사에 대한 배경을 읽으면, 케인즈의 거시경제학 이론을 더 깊이 이해할 수 있다.
#
# 3. 추천 강의 목록:
# - 추천 1: 거시경제학 (1041)
#   이유: 케인즈의 거시경제학 이론을 직접적으로 배울 수 있는 강의를 추천한다. 이 강의를 통해 거시경제학의 이론과 원리를 직접적으로 이해할 수 있다.
# - 추천 2: 공공 경제학 (1049)
#   이유: 케인즈의 거시경제학 이론을 이해하기 위해 공공 경제학 강의를 추천한다. 공공 경제학 강의는 공공 재정과 정책의 경제학적 이론을 다루므로, 케인즈의 거시경제학 이론과 관련된 이론을 더 깊이 이해할 수 있다.
#
# ========================= 실제 생성 종료 ============================================
#
# 1. 추천 도서 목록:
# - 추천 1: 자본의 한계 (데이비드 하비)
#   이유: 케인즈의 거

# %%
# 사용자 질의 테스트
query = "미시경제학에서 시장 실패를 해결하기 위한 정부 개입의 주요 사례는 무엇인가요?"
response = handle_query(query, syllabus_store, bibliography_store)

print("추천 결과:")
print(response["generated_text"]) # Access the 'generated_text' key directly
# Out:
# 추천 결과:
#
# 당신은 서지 및 강의 정보를 분석하여 추천하는 AI 비서입니다.
# 아래 제공된 정보(context)와 <question> 태그 안에 있는 사용자 질문을 기반으로 **<지정 응답 형식>만** 따르세요.
# 하나, 질문에 대해 알맞은 도서를 추천하고 이유를 제시하라.
# 둘, 추천 도서에 대해 학습 단계별 로드맵을 작성하고, 각 단계에 대한 이유를 제시하라.
# 셋, 질문에 대해 알맞은 강의를 추천하고 이유를 제시하라.
#
# <정보>
# 실라버스 정보:
# 강의명: 거시경제학, 강의 번호: 1041, 주관 학과: 경제학
# 국가 경제와 정책의 영향을 다루는 거시경제학 원리를 탐구합니다.
# 강의명: 미시경제학, 강의 번호: 1040, 주관 학과: 경제학
# 소비자의 선택과 기업의 생산 결정을 분석하는 미시경제학 이론을 학습합니다.
#
# 서지 정보:
# 도서명: 재정학과 공공정책, 저자: Jonathan Gruber, 출판사: 시그마프레스, ISBN: 624179
# 『재정학과 공공정책』은 재정학과 공공정책에 관한 입문서이다. 이 책은 재정학이 무엇인지 질문하면서, 정부는 언제 시장에 개입해야 하는지, 어떻게 개입해야 하는지, 이러한 정부의입니다.
# 도서명: 이단의 경제학, 저자: 조지프 스티글리츠, 출판사: 시대의창, ISBN: 740956
# ‘워싱턴 합의’ 신자유주의 경제 정책을 신랄하게 비판하고, 거시경제 정책과 자유화 정책을 수립할 때 개발도상국의 구체적인 상황에 주의를 기울여야 한다고 주장하면서 대안을 제시하는입니다.
# </정보>
#
# <질문>
# 미시경제학에서 시장 실패를 해결하기 위한 정부 개입의 주요 사례는 무엇인가요?
# </질문>
#
# <지정 응답 형식>:
# 1. 추천 도서 목록:
# - 추천 1: [도서명] (저자)
#   이유: [추천 이유]
# - 추천 2: [도서명] (저자)
#   이유: [추천 이유]
#
# 2. 도서 로드맵:
# - 단계 1: [도서명] (저자)
#   이유: [이 도서를 먼저 읽어야 하는 이유]
# - 단계 2: [도서명] (저자)
#   이유: [이 도서를 다음 단계로 추천하는 이유]
#
# 3. 추천 강의 목록:
# - 추천 1: [강의명]
#   이유: [추천 이유]
# - 추천 2: [강의명]
#   이유: [추천 이유]
# ========================= 실제 생성 종료 =======================================
# </지정 응답 형식>
#
# 반드시 위 <지정 응답 형식>만 사용하여 작성하세요. 형식을 벗어나거나 불필요한 추가 정보를 포함하지 마세요.
# 지정 응답 형식에 따른 생성이 끝나면 추가, 반복 생성 없이 종료하세요.
# ========================= 실제 생성 ============================================
# 1. 추천 도서 목록:
# - 추천 1: 재정학과 공공정책 (저자: Jonathan Gruber)
#   이유: 재정학과 공공정책에 대한 입문서로, 정부의 개입과 재정학에 대한 기초적인 이해를 제공합니다.
# - 추천 2: 이단의 경제학 (저자: 조지프 스티글리츠)
#   이유: 거시경제학과 자유화 정책에 대한 깊이 있는 분석을 제공하며, 시장 실패 해결에 대한 다양한 시각을 제시합니다.
#
# 2. 도서 로드맵:
# - 단계 1: 재정학과 공공정책 (저자: Jonathan Gruber)
#   이유: 재정학과 공공정책은 거시경제학의 기본 개념을 이해하기 위한 중요한 도서로, 정부의 개입과 재정학에 대한 기초적인 이해를 제공합니다. 이를 통해 미시경제학의 개념을 더 잘 이해할 수 있습니다.
# - 단계 2: 이단의 경제학 (저자: 조지프 스티글리츠)
#   이유: 이단의 경제학은 거시경제학의 이론적 기초를 이해하기 위한 중요한 도서로, 시장 실패 해결에 대한 다양한 시각을 제시합니다. 이를 통해 미시경제학의 개념을 더 잘 이해할 수 있습니다.
#
# 3. 추천 강의 목록:
# - 추천 1: 거시경제학 (강의 번호: 1041)
#   이유: 거시경제학 강의는 국가 경제와 정책에 대한 이해를 제공하며, 정부의 개입과 거시경제학의 원리를 탐구합니다. 이를 통해 미시경제학의 개념을 더 잘 이해할 수 있습니다.
# - 추천 2: 미시경제학 (강의 번호: 1040)
#   이유: 미시경제학 강의는 소비자의 선택과 기업의 생산 결정을 분석하는 이론을 학습합니다. 이를 통해 거시경제학의 개념을 더 잘 이해할 수 있습니다.
#
# ========================= 실제 생성 종료 ========================================
#
# 1. 추천 도서 목록:
# - 추천 1: 재정학과 공공정책 (저자: Jonathan Gruber)
#   이유: 재정학과 공공정책에 대한 입문서로,

# %%
# 사용자 질의 테스트
query = "게임 이론이 기업 간 경쟁 전략 분석에 어떻게 활용되는지 설명해주세요."
response = handle_query(query, syllabus_store, bibliography_store)

print("추천 결과:")
print(response["generated_text"]) # Access the 'generated_text' key directly
# Out:
# 추천 결과:
#
# 당신은 서지 및 강의 정보를 분석하여 추천하는 AI 비서입니다.
# 아래 제공된 정보(context)와 <question> 태그 안에 있는 사용자 질문을 기반으로 **<지정 응답 형식>만** 따르세요.
# 하나, 질문에 대해 알맞은 도서를 추천하고 이유를 제시하라.
# 둘, 추천 도서에 대해 학습 단계별 로드맵을 작성하고, 각 단계에 대한 이유를 제시하라.
# 셋, 질문에 대해 알맞은 강의를 추천하고 이유를 제시하라.
#
# <정보>
# 실라버스 정보:
# 강의명: 게임 이론, 강의 번호: 1043, 주관 학과: 경제학
# 전략적 의사결정을 위한 게임 이론을 학습합니다.
# 강의명: 데이터 기반 마케팅, 강의 번호: 1033, 주관 학과: 경영학
# 데이터 기반의 마케팅 의사결정 및 전략 수립 기법을 탐구합니다.
#
# 서지 정보:
# 도서명: Competitive Strategy, 저자: Charlotte, 출판사: Publisher32, ISBN: 733237
# Competitive Strategy은 실라버스에 포함된 참고문헌으로 학습 자료로 사용됩니다.
# 도서명: Computer Architecture: A Quantitative Approach, 저자: John L. Hennessy, David A. Patterson, 출판사: Publisher25, ISBN: 112225
# 컴퓨터 아키텍처의 정량적 접근법과 성능 분석을 다룬 도서입니다.
# </정보>
#
# <질문>
# 게임 이론이 기업 간 경쟁 전략 분석에 어떻게 활용되는지 설명해주세요.
# </질문>
#
# <지정 응답 형식>:
# 1. 추천 도서 목록:
# - 추천 1: [도서명] (저자)
#   이유: [추천 이유]
# - 추천 2: [도서명] (저자)
#   이유: [추천 이유]
#
# 2. 도서 로드맵:
# - 단계 1: [도서명] (저자)
#   이유: [이 도서를 먼저 읽어야 하는 이유]
# - 단계 2: [도서명] (저자)
#   이유: [이 도서를 다음 단계로 추천하는 이유]
#
# 3. 추천 강의 목록:
# - 추천 1: [강의명]
#   이유: [추천 이유]
# - 추천 2: [강의명]
#   이유: [추천 이유]
# ========================= 실제 생성 종료 =======================================
# </지정 응답 형식>
#
# 반드시 위 <지정 응답 형식>만 사용하여 작성하세요. 형식을 벗어나거나 불필요한 추가 정보를 포함하지 마세요.
# 지정 응답 형식에 따른 생성이 끝나면 추가, 반복 생성 없이 종료하세요.
# ========================= 실제 생성 ============================================
# 1. 추천 도서 목록:
# - 추천 1: Competitive Strategy (Charlotte)
#   이유: 게임 이론이 기업 간 경쟁 전략 분석에 어떻게 활용되는지를 이해하기 위해 도서의 주요 개념과 예시를 통해 학습할 수 있습니다.
# - 추천 2: Computer Architecture: A Quantitative Approach (John L. Hennessy, David A. Patterson)
#   이유: 게임 이론과 데이터 기반 마케팅을 다룬 강의와의 상호작용을 이해하기 위해 컴퓨터 아키텍처의 정량적 접근법과 성능 분석을 배울 수 있습니다.
#
# 2. 도서 로드맵:
# - 단계 1: Competitive Strategy (Charlotte)
#   이유: 게임 이론이 기업 간 경쟁 전략 분석에 어떻게 활용되는지를 이해하기 위해 도서의 주요 개념과 예시를 통해 학습할 수 있습니다.
# - 단계 2: Computer Architecture: A Quantitative Approach (John L. Hennessy, David A. Patterson)
#   이유: 게임 이론과 데이터 기반 마케팅을 다룬 강의와의 상호작용을 이해하기 위해 컴퓨터 아키텍처의 정량적 접근법과 성능 분석을 배울 수 있습니다.
#
# 3. 추천 강의 목록:
# - 추천 1: Game Theory (강의 번호: 1043)
#   이유: 게임 이론의 주요 개념과 예시를 통해 학습할 수 있으며, 전략적 의사결정을 위한 게임 이론의 적용을 이해할 수 있습니다.
# - 추천 2: Data-Driven Marketing (강의 번호: 1033)
#   이유: 데이터 기반 마케팅의 기법과 전략을 이해하기 위해 강의의 주요 개념과 예시를 통해 학습할 수 있습니다. 강의와 게임 이론의 상호작용을 이해하기 위해 컴퓨터 아키텍처의 정량적 접근법과 성능 분석을 배울 수 있습니다.
#
# ========================= 실제 생성 종료 ========================================
#
# 1. 추천 도서 목록:
# - 추천 1: Competitive Strategy (Charlotte)
#   이유: 게임 이론이 기업 간 경쟁 전략 분석에 어떻게 활용되는지를 이해하기 위해 도서의 주요 개념과 예시를 통해 학습할 수 있습니다.
# - 추천 2: Computer Architecture

# %%
# 사용자 질의 테스트
query = "효용 이론이 소비자의 선택 행동을 분석하는 데 어떻게 적용될 수 있나요?"
response = handle_query(query, syllabus_store, bibliography_store)

print("추천 결과:")
print(response["generated_text"]) # Access the 'generated_text' key directly
# Out:
# 추천 결과:
#
# 당신은 서지 및 강의 정보를 분석하여 추천하는 AI 비서입니다.
# 아래 제공된 정보(context)와 <question> 태그 안에 있는 사용자 질문을 기반으로 **<지정 응답 형식>만** 따르세요.
# 하나, 질문에 대해 알맞은 도서를 추천하고 이유를 제시하라.
# 둘, 추천 도서에 대해 학습 단계별 로드맵을 작성하고, 각 단계에 대한 이유를 제시하라.
# 셋, 질문에 대해 알맞은 강의를 추천하고 이유를 제시하라.
#
# <정보>
# 실라버스 정보:
# 강의명: 미시경제학, 강의 번호: 1040, 주관 학과: 경제학
# 소비자의 선택과 기업의 생산 결정을 분석하는 미시경제학 이론을 학습합니다.
# 강의명: 소비자 행동 분석, 강의 번호: 1027, 주관 학과: 경영학
# 소비자 행동 데이터 분석과 마케팅 전략 수립 기법을 탐구합니다.
#
# 서지 정보:
# 도서명: 고수들의 계량경제학, 저자: Jorn-steffen Pischke, Joshua D. Angrist, 출판사: 시그마프레스, ISBN: 827044
# 응용 계량경제학은 원래 데이터를 다루는 과학이다. 계량은 다양한 인간사들의 원인과 결과를 풀어내기 위해 경제학자들이 사용하는 여러 가지 통계 방법을 포괄한다. 계량 연구에입니다.
# 도서명: Consumer Behavior, 저자: Sophia, 출판사: Publisher6, ISBN: 899485
# Consumer Behavior은 실라버스에 포함된 참고문헌으로 학습 자료로 사용됩니다.
# </정보>
#
# <질문>
# 효용 이론이 소비자의 선택 행동을 분석하는 데 어떻게 적용될 수 있나요?
# </질문>
#
# <지정 응답 형식>:
# 1. 추천 도서 목록:
# - 추천 1: [도서명] (저자)
#   이유: [추천 이유]
# - 추천 2: [도서명] (저자)
#   이유: [추천 이유]
#
# 2. 도서 로드맵:
# - 단계 1: [도서명] (저자)
#   이유: [이 도서를 먼저 읽어야 하는 이유]
# - 단계 2: [도서명] (저자)
#   이유: [이 도서를 다음 단계로 추천하는 이유]
#
# 3. 추천 강의 목록:
# - 추천 1: [강의명]
#   이유: [추천 이유]
# - 추천 2: [강의명]
#   이유: [추천 이유]
# ========================= 실제 생성 종료 =======================================
# </지정 응답 형식>
#
# 반드시 위 <지정 응답 형식>만 사용하여 작성하세요. 형식을 벗어나거나 불필요한 추가 정보를 포함하지 마세요.
# 지정 응답 형식에 따른 생성이 끝나면 추가, 반복 생성 없이 종료하세요.
# ========================= 실제 생성 ============================================
# 1. 추천 도서 목록:
# - 추천 1: 고수들의 계량경제학 (저자: Jorn-steffen Pischke, Joshua D. Angrist)
#   이유: 효용 이론이 소비자의 선택 행동을 분석하는 데 중요하게 사용되는 계량경제학 이론을 이해하기 위해 이 도서를 읽어야 합니다.
# - 추천 2: Consumer Behavior (저자: Sophia)
#   이유: 실라버스에 포함된 참고문헌으로 소비자의 선택 행동을 분석하는 데 필요한 기본적인 지식을 얻을 수 있습니다.
#
# 2. 도서 로드맵:
# - 단계 1: 고수들의 계량경제학 (저자: Jorn-steffen Pischke, Joshua D. Angrist)
#   이유: 효용 이론이 소비자의 선택 행동을 분석하는 데 중요하게 사용되는 계량경제학 이론을 이해하기 위해 이 도서를 먼저 읽어야 합니다.
# - 단계 2: Consumer Behavior (저자: Sophia)
#   이유: 효용 이론이 소비자의 선택 행동을 분석하는 데 필요한 기본적인 지식을 얻기 위해 이 도서를 읽어야 합니다.
#
# 3. 추천 강의 목록:
# - 추천 1: 미시경제학 강의 (강의 번호: 1040)
#   이유: 소비자의 선택과 기업의 생산 결정을 분석하는 미시경제학 이론을 학습함으로써 효용 이론이 소비자의 선택 행동에 어떻게 적용될 수 있는지 이해할 수 있습니다.
# - 추천 2: 소비자 행동 분석 강의 (강의 번호: 1027)
#   이유: 소비자 행동 데이터 분석과 마케팅 전략 수립 기법을 탐구함으로써 효용 이론이 소비자의 선택 행동에 어떻게 적용될 수 있는지 이해할 수 있습니다.
#
# ========================= 실제 생성 종료 ============================================
#
# 1. 추천 도서 목록:
# - 추천 1: 고수들의 계량경제학 (저자: Jorn-steffen Pischke, Joshua D. Angrist)
#   이유: 효용 이론이 소비자의 선택 행동을 분석하는 데 중요하게 사용되는 계량경제학 이론을 이해하기 위해 이 도서를 읽어야 합니다.
# - 추천 2: Consumer Behavior (저자: Sophia
